# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# 1000개의 x, y좌표를 랜덤으로 생성하여 점들을 찍는다.(units)
units = 1000
centroids = 10
dot = np.random.rand(units, 2)
plt.scatter(dot[:,0], dot[:,1], marker = "o", color = "gray", s=20)

# 10개의 x, y좌표를 랜덤으로 생성하여 점들을 찍는다(centroids)
dot = np.random.rand(centroid, 2)
plt.scatter(dot[:,0], dot[:,1], marker = "1", color = "red", s=100)
plt.show()
plt.savefig("")
